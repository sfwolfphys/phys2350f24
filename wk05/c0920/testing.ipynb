# %% [markdown]
# Testing functions

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from projectile import *

# %%
m=1
c=0.005
dt = 0.1

genProjectilePlot(0,100,50,20, dt, m, c)
